# %%
# %pip install -Uq langchain langchain-core
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import PromptTemplate
# Out:
# /Users/woocheolseong/work/knu_python/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
input_str = "대전은 어떤도시인가요?"

prompt_template_1 = PromptTemplate(
    template=input_str
)

print(prompt_template_1)

invoke_result_1 = prompt_template_1.invoke({})

print(type(invoke_result_1))
print(invoke_result_1)

print(invoke_result_1.to_messages())
# Out:
# input_variables=[] input_types={} partial_variables={} template='대전은 어떤도시인가요?'
# <class 'langchain_core.prompt_values.StringPromptValue'>
# text='대전은 어떤도시인가요?'
# [HumanMessage(content='대전은 어떤도시인가요?', additional_kwargs={}, response_metadata={})]

# %%
prompt_template_2 = PromptTemplate.from_template(
    input_str
)

print(prompt_template_2)

invoke_result_2 = prompt_template_2.invoke({})

print(type(invoke_result_2))
print(invoke_result_2)

print(invoke_result_2.to_messages())
# Out:
# input_variables=[] input_types={} partial_variables={} template='대전은 어떤도시인가요?'
# <class 'langchain_core.prompt_values.StringPromptValue'>
# text='대전은 어떤도시인가요?'
# [HumanMessage(content='대전은 어떤도시인가요?', additional_kwargs={}, response_metadata={})]

# %%
# 템플릿 변수
# {변수명}
# "{city}에서 가장 유명한 {target}을 2개만 소개해주세요."

prompt_template_3 = PromptTemplate(
    template="{city}에서 가장 유명한 {target}을 2개만 소개해주세요.",
    input_variables=[ 'city', 'target' ],
)

prompt_template_4 = PromptTemplate.from_template("{city}에서 가장 유명한 {target}을 2개만 소개해주세요.")

# %%
print(prompt_template_3.input_variables)
print(prompt_template_4.input_variables)
# Out:
# ['city', 'target']
# ['city', 'target']

# %%
prompt_value_3 = prompt_template_3.invoke({
    'city': '대전',
    'target':'음식'
})

print(prompt_value_3.to_string())

# -- 

prompt_value_4 = prompt_template_3.format(city="천안", target="대학교")

print(prompt_value_4)
print(type(prompt_value_4))
# Out:
# 대전에서 가장 유명한 음식을 2개만 소개해주세요.
# 천안에서 가장 유명한 대학교을 2개만 소개해주세요.
# <class 'str'>

# %%
# %pip install -Uq langchain-groq
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -Uq dotenv
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.1-8b-instant"
)

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate.from_template("{city}에시 유명한 관광지 2개를 알려줘.")

prompt = template.invoke({'city': '대전'})

result = model.invoke(prompt)

print(type(result))
print(result.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 대전광역시의 유명한 관광지 2개는 다음과 같습니다.
#
# 1. 해방의전야기념관 : 대전광역시 중구 중마동에 위치한 해방의전야기념관은 한국의 해방을 기념하는 곳으로 1945년 8월 15일에 일본의 식민 통치가 끝나고 한국이 해방되는 것을 기념하는 곳입니다. 기념관은 1985년에 개장하였으며, 한국의 독립을 축하하는 행사와 한국의 역사에 대한 교육을目的으로 운영하고 있습니다.
#
# 2. 대전월드컵경기장 : 대전광역시 유성구에 위치한 대전월드컵경기장은 2001년 FIFA 월드컵을 개최하기 위해 건설되었으며, 2001년 FIFA 월드컵의 주경기장으로 사용되었습니다. 경기장에는 40,500석의 좌석이 있으며, 축구 경기뿐만 아니라 음악과 축제 등의 행사도 개최하고 있습니다.
