# %%
# %pip install -Uq langchain langchain-core
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate, ChatPromptTemplate

system_msg = SystemMessagePromptTemplate.from_template("너는 도움이 되는 어시스턴트야. 한국어로만 대답해.")
user_msg = HumanMessagePromptTemplate.from_template("{city}에서 유명한 음식 3가지만 알려줘")

chat_template = ChatPromptTemplate.from_messages( [ system_msg, user_msg ] )

print(chat_template)
# Out:
# input_variables=['city'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='너는 도움이 되는 어시스턴트야. 한국어로만 대답해.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['city'], input_types={}, partial_variables={}, template='{city}에서 유명한 음식 3가지만 알려줘'), additional_kwargs={})]
