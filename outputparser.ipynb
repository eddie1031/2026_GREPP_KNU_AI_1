# %% [markdown]
# ## OutputParser
# - StrOutputParser
#   - https://reference.langchain.com/python/langchain-core/output_parsers/string/StrOutputParser
# - JsonOutputParser
#   - https://reference.langchain.com/python/langchain-core/output_parsers/json/JsonOutputParser
# - PydanticOutputParser
#   - https://reference.langchain.com/python/langchain-core/output_parsers/pydantic/PydanticOutputParser
# - CommaSeparatorOutputParser
#   - https://reference.langchain.com/python/langchain-core/output_parsers/list/CommaSeparatedListOutputParser
# - ListOutputParser
#   - https://reference.langchain.com/python/langchain-core/output_parsers/list/ListOutputParser
# - StructuredOutputPaser -> with_structured_output()
#   - https://reference.langchain.com/python/langchain-classic/output_parsers/structured/StructuredOutputParser
#   - https://reference.langchain.com/python/langchain-anthropic/chat_models/ChatAnthropic/with_structured_output

# %%
# %pip install -Uq langchain-groq dotenv
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

model = ChatGroq(
    model="llama-3.1-8b-instant"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "대전에 대해서 100글자로 설명해줘")
    ]
)

parser = StrOutputParser()

# msg = prompt.invoke({})

result = model.invoke(prompt.invoke({}))

parsed = parser.invoke(result)

print(parsed)
# Out:
# 대전은 한국의 충청권 지역에 있는 중소 도시입니다. 도시의 명칭은 '대동성'에서 유래되었으며, 조선 시대에 대동교를 중심으로 성곽이 형성되었다는 전설에서 이름이 유래했습니다. 1950년 한국 전쟁 이전에는 대전은 소규모 마을로しか 존재하지 않았지만, 전쟁 이후 도시가 급격히 성장하여 현재는 인구 1,500만 명 이상의 도시로 성장했습니다.
