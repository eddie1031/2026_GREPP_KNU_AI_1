# %%
# 프롬프트 -> 모델 -> 파싱(문자열)

from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "너는 관광가이드 역할을 수행할거야. 한국어로 대답해줘"),
        ("human", "{country}의 {city}에서 가장 유명한 {target}을 3개 소개해줘.")
    ]
)

model = ChatGroq(
    model='llama-3.1-8b-instant'
)

parser = StrOutputParser()

chain = prompt | model | parser


result = chain.invoke({
    'country': '대한민국',
    'city': '대전',
    'target': '관광지'
})

print(result)
# Out:
# /Users/woocheolseong/work/knu_python/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# 대전은 한국의 중부 지역에 위치한 도시로, 다양한 역사적 유적지와 문화적인 명소가 많습니다. 대전의 가장 유명한 관광지 3개를 소개해 드리겠습니다.
#
# 1. **국립중앙박물관**: 대전의 대표적인 문화 유적지입니다. 1945년부터 개관한 한국 최초의 박물관으로, 한국의 역사, 문화, 예술 등 다양한 분야의 전시를 하고 있습니다. 유명한 전시로는 삼국유사, 고구려의 유물, 그리고 조선시대의 왕릉 유물 등이 있습니다.
#
# 2. **덕진구청장기마을**: 한국전쟁 이전에 유명한 마을로, 당시의 한국의 삶을 그대로 느낄 수 있습니다. 1940년대 및 1950년대에 지어진 주택들이 보존되어 있으며, 주민들이 살아가던 모습을 보여줍니다. 이곳은 한국전쟁 이전의 한국의 사회, 경제, 문화를 이해할 수 있는 좋은 장소입니다.
#
# 3. **대전월드**: 대전의 대표적인 THEME 파크로, 한국 최초의 THEME 파크로 알려져 있습니다. 2016년 4월 29일까지 '대전국제엑스포지구'로 불리던 장소에서 2006년 7월 7일 여름 개장하여, 2016년 4월 29일까지 운영되었습니다.
#
# 이곳은 다양한 놀이기구, 공연, 전시회, 쇼핑몰, 식당 등이 있으며, 가족과 함께 즐거운 시간을 보낼 수 있는 곳입니다.
#
# 이러한 대전의 유명한 관광지 중 하나를 방문해 보세요.
