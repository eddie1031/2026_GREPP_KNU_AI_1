# %%
# %pip install -Uq langchain langchain-core
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.messages import BaseMessage

msg = BaseMessage(
    type="Human",
    content="대전은 어떤 도시인가요?",
)

print(msg)
# Out:
# content='대전은 어떤 도시인가요?' additional_kwargs={} response_metadata={} type='Human'

# %%
from langchain_core.messages import HumanMessage

msg2 = HumanMessage(
    content="대전은 어떤 도시인가요?"
)

print(msg2)
print(msg2.type)
# Out:
# content='대전은 어떤 도시인가요?' additional_kwargs={} response_metadata={}
# human

# %%
from langchain_core.messages import SystemMessage

msg3 = SystemMessage(
    content="너는 10년차 시니어 개발자 역할을 수행할거야. 한국어로만 대답해"
)

print(msg3)
print(msg3.type)
# Out:
# content='너는 10년차 시니어 개발자 역할을 수행할거야. 한국어로만 대답해' additional_kwargs={} response_metadata={}
# system
